# %%
import os
import json
import yaml
import shutil
import xml.etree.ElementTree as ET
from pathlib import Path
from tifffile import TiffFile

# %% [markdown]
# # Define paths

# %%
input_root = "/teradata/sbdubey/deepcell-experiments-data/intestine-codex-stanford/data-original/"
output_root = "/teradata/sbdubey/deepcell-experiments-data/intestine-codex-stanford/input-data/"

# %% [markdown]
# # Function to extract HubMAP ID

# %%
def get_hubmap_id(dir_name):
    # Extract HBM###.XXXX.### part and remove dots
    parts = dir_name.split('-')[0]
    return parts.replace('.', '')

# %% [markdown]
# # Function to extract MPP from OME-TIFF

# %%
def extract_mpp(tiff_path):
    with TiffFile(tiff_path) as tif:
        ome_xml = tif.ome_metadata
        
        # Parse PhysicalSizeX and unit
        if 'PhysicalSizeX="' in ome_xml:
            start = ome_xml.find('PhysicalSizeX="') + 15
            end = ome_xml.find('"', start)
            physical_size_x = float(ome_xml[start:end])
            
            start = ome_xml.find('PhysicalSizeXUnit="') + 19
            end = ome_xml.find('"', start)
            unit = ome_xml[start:end]
            
            # Convert to microns
            if unit == 'nm':
                mpp = physical_size_x / 1000
            elif unit == 'µm' or unit == 'um':
                mpp = physical_size_x
            elif unit == 'mm':
                mpp = physical_size_x * 1000
            elif unit == 'm':
                mpp = physical_size_x * 1000000
            else:
                mpp = physical_size_x
                
            return round(mpp, 5)
    return None

# %% [markdown]
# # Function to extract channel names from OME-TIFF

# %%
def extract_channels_from_tiff(tiff_path):
    with TiffFile(tiff_path) as tif:
        ome_xml = tif.ome_metadata
        
        # Parse OME-XML to extract channels
        root = ET.fromstring(ome_xml)
        ns = {"ome": "http://www.openmicroscopy.org/Schemas/OME/2016-06"}
        channels = [c.attrib.get("Name") for c in root.findall(".//ome:Channel", ns)]
        
        return channels

# %% [markdown]
# # Updated function to create YAML config

# %%
def create_yaml_config(json_path, tiff_path, hubmap_id):
    with open(json_path, 'r') as f:
        config = json.load(f)
    
    # Extract nucleus and cell channel names from JSON
    nucleus_channel = config['report']['reg1']['nucleus_channel']
    cell_channel = config['report']['reg1']['cell_channel']
    
    # Extract channel names directly from TIFF
    channel_names = extract_channels_from_tiff(tiff_path)
    
    # Get channel indices from the actual TIFF channels
    try:
        nucleus_idx = channel_names.index(nucleus_channel)
    except ValueError:
        raise ValueError(f"Nucleus channel '{nucleus_channel}' not found in TIFF channels")
    
    try:
        cell_idx = channel_names.index(cell_channel)
    except ValueError:
        raise ValueError(f"Cell channel '{cell_channel}' not found in TIFF channels")
    
    # Extract MPP
    mpp = extract_mpp(tiff_path)
    
    # Build YAML structure
    yaml_data = {
        'image_path': f'{hubmap_id}.ome.tiff',
        'use_wsi': True,
        'MPP': mpp,
        'channels': [
            {'name': nucleus_channel, 'number': nucleus_idx},
            {'name': cell_channel, 'number': cell_idx}
        ],
        'markers': [
            {'name': name, 'number': idx} 
            for idx, name in enumerate(channel_names)
        ]
    }
    
    return yaml_data

# %% [markdown]
# # Main processing loop

# %%
# Create output root if it doesn't exist
os.makedirs(output_root, exist_ok=True)

# Process each directory
input_dirs = [d for d in os.listdir(input_root) if os.path.isdir(os.path.join(input_root, d))]

for dir_name in input_dirs:
    print(f"Processing: {dir_name}")
    
    # Get HubMAP ID
    hubmap_id = get_hubmap_id(dir_name)
    
    # Define paths
    input_dir = os.path.join(input_root, dir_name)
    json_path = os.path.join(input_dir, 'pipelineConfig.json')
    
    # Check for either TIFF filename. (** Make sure that you check the path is it changes for some other data)
    tiff_path_1 = os.path.join(input_dir, 'reg001_expr.ome.tiff')
    tiff_path_2 = os.path.join(input_dir, 'reg1_stitched_expressions.ome.tif')
    
    if os.path.exists(tiff_path_1):
        tiff_path = tiff_path_1
    elif os.path.exists(tiff_path_2):
        tiff_path = tiff_path_2
    else:
        print(f"  ERROR: No TIFF file found")
        continue
    
    # Create output directory
    output_dir = os.path.join(output_root, hubmap_id[:13])
    os.makedirs(output_dir, exist_ok=True)
    
    try:
        # Create YAML config
        yaml_data = create_yaml_config(json_path, tiff_path, hubmap_id)
        
        # Write YAML file
        yaml_path = os.path.join(output_dir, f'{hubmap_id}_config.yaml')
        with open(yaml_path, 'w') as f:
            yaml.dump(yaml_data, f, default_flow_style=False, sort_keys=False)
        
        # Copy TIFF file with new name
        new_tiff_path = os.path.join(output_dir, f'{hubmap_id}.ome.tiff')
        shutil.copy2(tiff_path, new_tiff_path)
        
        print(f"  Created: {hubmap_id}")
    except Exception as e:
        print(f"  ERROR: {e}")
        

print("\nProcessing complete!")
# Out:
# Processing: HBM233.GTZN.466-b38730b2633e0b088619f9bcd514ba13
#   Created: HBM233GTZN466
# Processing: HBM244.TVNH.734-168050d20802e0c0d91fd5f51ce550da
#   Created: HBM244TVNH734
# Processing: HBM245.NHMB.685-bc68fe67a089ab19c1449de6d0703d71
#   Created: HBM245NHMB685
# Processing: HBM253.MXKW.373-ac169bbda02d0c2832c01f70375ff6dc
#   Created: HBM253MXKW373
# Processing: HBM292.FCMS.497-6bdd149dc47782aefdd0e23599708183
#   Created: HBM292FCMS497
# Processing: HBM293.LGZW.236-c92332aa7e244be5bad1c27c80fcd343
#   Created: HBM293LGZW236
# Processing: HBM334.RPTP.997-47b8410d1c51b23e7fb1a721c53a493f
#   Created: HBM334RPTP997
# Processing: HBM352.MDZF.598-01510a4fb90fd303bd48c4cd51cdd14c
#   Created: HBM352MDZF598
# Processing: HBM396.FNQW.543-87922a42fa8bc7ab29a4d2d5374afbb4
#   Created: HBM396FNQW543
# Processing: HBM398.SWKV.256-ff77fcae7f6d9b5b7b8741c282677eef
#   Created: HBM398SWKV256
# Processing: HBM423.MMGW.744-3e800f0cd138b989b935fb94e7938617
#   Created: HBM423MMGW744
# Processing: HBM423.QJJR.545-b98ca5a13b6b7482fe7acbeeb13f255d
#   Created: HBM423QJJR545
# Processing: HBM429.DWKZ.323-a40043a8f837186f5a8827e44389c8d4
#   Created: HBM429DWKZ323
# Processing: HBM433.ZLWP.627-5318485b16983482401c3be24b6c42ad
#   Created: HBM433ZLWP627
# Processing: HBM443.XPDK.549-8b21db2002a5179b03532d183a4885eb
#   Created: HBM443XPDK549
# Processing: HBM475.DXDC.532-89e4944336dd47d32a50fe8aac049db1
#   Created: HBM475DXDC532
# Processing: HBM494.VNTQ.422-e8c159fdeabc3c0bf12345b9b1ec99c9
#   Created: HBM494VNTQ422
# Processing: HBM523.XHWW.384-31c38b51c975d50d7faeb829507223ff
#   Created: HBM523XHWW384
# Processing: HBM524.VWGB.378-eaad67a6c6e891ea72cc397c26bd607f
#   Created: HBM524VWGB378
# Processing: HBM538.PGFT.538-63d000170e475af142f6e8673de5eb0f
#   Created: HBM538PGFT538
# Processing: HBM564.DSPG.945-d84fb871861bf966850943b4ab2a9134
#   Created: HBM564DSPG945
# Processing: HBM578.XJZQ.389-39331497ab35a84812e04389e8f402d2
#   Created: HBM578XJZQ389
# Processing: HBM587.VTDD.789-fafec5ab4f5c7bb0564d6e7673c316e5
#   Created: HBM587VTDD789
# Processing: HBM599.BFHP.494-289c13f8ec809a7ed138262eb2a6d946
#   Created: HBM599BFHP494
# Processing: HBM625.BPDM.987-a9afd0984321fcd25e72bc049f434a89
#   Created: HBM625BPDM987
# Processing: HBM629.DBKM.347-0173b4e2b3f576109a5aca880a3bdadc
#   Created: HBM629DBKM347
# Processing: HBM634.MSKL.575-8d86e6c899e80d0f5f95604eb4ad492e
#   Created: HBM634MSKL575
# Processing: HBM636.GTZK.259-35d53aa621e25665b1d239f1d89befb2
#   Created: HBM636GTZK259
# Processing: HBM644.QKZS.857-7eea0c4c41745d2d54f9796bc5b57d79
#   Created: HBM644QKZS857
# Processing: HBM654.MLRM.725-66714459648e063073aa34a311b280d6
#   Created: HBM654MLRM725
# Processing: HBM657.JVPV.825-76d3efd17b6fc83aaac13e961824c5ae
#   Created: HBM657JVPV825
# Processing: HBM658.HHLH.689-9d8677a799797c76a8205988cd3888b2
#   Created: HBM658HHLH689
# Processing: HBM658.WGPT.978-2a12226aa56c8ac552c53c04032a91fb
#   Created: HBM658WGPT978
# Processing: HBM676.VBCN.445-e695c48cb6be99479daefaf372743f65
#   Created: HBM676VBCN445
# Processing: HBM685.PCCJ.427-c8fa615fb884c7b51d08c0cf35debfee
#   Created: HBM685PCCJ427
# Processing: HBM725.QFKT.594-06e99e38b27d5e3206082cb1a9d5a898
#   Created: HBM725QFKT594
# Processing: HBM735.PSTF.274-f0597185d99c05b19c1189f9d14c8853
#   Created: HBM735PSTF274
# Processing: HBM749.PPQP.849-9e58a221d1f73f84924dabed476379d1
#   Created: HBM749PPQP849
# Processing: HBM753.VDXD.934-c18105af8ff3a52bb539868a9fe2252f
#   Created: HBM753VDXD934
# Processing: HBM754.SFBF.894-a02808d3f57cb7d17c213bb8e50f6be6
#   Created: HBM754SFBF894
# Processing: HBM776.FNRJ.959-7b2b9029035d46c4ef8306fa82c8e58e
#   Created: HBM776FNRJ959
# Processing: HBM776.SDCW.837-8da8f27977d946b8c912d42c8827b55c
#   Created: HBM776SDCW837
# Processing: HBM777.TLQL.487-550f3ef14b113c24fd21b8b0750bf078
#   Created: HBM777TLQL487
# Processing: HBM784.TKZX.992-2e65eeef2dd18bee2a0baf1cec6d35a1
#   Created: HBM784TKZX992
# Processing: HBM795.GWKV.825-aa54aad994ca8a64fa52b3f3945c01b7
#   Created: HBM795GWKV825
# Processing: HBM829.QZQP.626-ad7c2d2cc423d0324fc1bba43042a515
#   Created: HBM829QZQP626
# Processing: HBM837.RHNC.533-caa55d2b3f62070ea878054c08b0434e
#   Created: HBM837RHNC533
# Processing: HBM842.LQDP.877-dceadbb36871071f30c308ca091fbdc8
#   Created: HBM842LQDP877
# Processing: HBM886.NTZN.682-fc21e53fb1976b3cf7ca817b18ad2979
#   Created: HBM886NTZN682
# Processing: HBM889.KDGM.632-768b7adb649959b6a4e354867595032d
#   Created: HBM889KDGM632
# Processing: HBM929.PRKH.522-89409b74d945fff98bb60afa9753cd0d
#   Created: HBM929PRKH522
# Processing: HBM937.XPRG.696-9a6f6ad6fc033ca6a4b994b13ddfb9ea
#   Created: HBM937XPRG696
# Processing: HBM942.WHFC.488-00cc71c7e1cddac60e794044079faeee
#   Created: HBM942WHFC488
# Processing: HBM946.GRVG.379-ae422532f260b3d6fc662aae69b05d33
#   Created: HBM946GRVG379
# Processing: HBM946.NWTV.278-0126deb572ee57c93e444ebc73de2b91
#   Created: HBM946NWTV278
# Processing: HBM953.LMWQ.235-10c0c11280c00f324259fe38e2291ee4
#   Created: HBM953LMWQ235
# Processing: HBM953.NPDJ.575-96be83f891e7a528f1d213c3c5e6ea44
#   Created: HBM953NPDJ575
# Processing: HBM959.BVWN.344-4158174807d97dccbd75d0b162edd9a3
#   Created: HBM959BVWN344
# Processing: HBM962.BFPH.344-cba4c1d05d8316f488c23a5ed20a68b2
#   Created: HBM962BFPH344
# Processing: HBM972.WNBG.933-e94cc122d000fa9343075cbfc2307eb5
#   Created: HBM972WNBG933
# Processing: HBM994.KDNT.678-e990a3b436bfad04d64400ad1c28c685
#   Created: HBM994KDNT678
# Processing: HBM995.WMDN.689-18ebd20158eaa72afa5728ec73e516f2
#   Created: HBM995WMDN689
# Processing: HBM996.CGFD.228-c945cbd75f2da373d1ccfe86694f9c34
#   Created: HBM996CGFD228
#
# Processing complete!

# %% [markdown]
# # Verify output

# %%
# List created directories
output_dirs = sorted([d for d in os.listdir(output_root) if os.path.isdir(os.path.join(output_root, d))])
print(f"Total directories created: {len(output_dirs)}")
print("\nFirst 5 directories:")
for d in output_dirs[:5]:
    files = os.listdir(os.path.join(output_root, d))
    print(f"  {d}: {files}")
# Out:
# Total directories created: 63
#
# First 5 directories:
#   HBM233GTZN466: ['HBM233GTZN466_config.yaml', 'HBM233GTZN466.ome.tiff']
#   HBM244TVNH734: ['HBM244TVNH734_config.yaml', 'HBM244TVNH734.ome.tiff']
#   HBM245NHMB685: ['HBM245NHMB685_config.yaml', 'HBM245NHMB685.ome.tiff']
#   HBM253MXKW373: ['HBM253MXKW373_config.yaml', 'HBM253MXKW373.ome.tiff']
#   HBM292FCMS497: ['HBM292FCMS497_config.yaml', 'HBM292FCMS497.ome.tiff']
