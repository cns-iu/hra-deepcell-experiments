# %%
import numpy as np 
import pandas as pd 
import os

# %%
df = pd.read_csv('/u/sbdubey/hubmap_descendants_map.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           64 non-null     int64
#  1   HuBMAP ID            64 non-null     object
#  2   last_uuid            64 non-null     object
#  3   total_descendants    64 non-null     int64
#  4   first_descendant_id  64 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.6+ KB

# %%
df.head(10)
# Out:
#    Unnamed: 0        HuBMAP ID                         last_uuid  \
# 0           0  HBM235.VKNJ.237  c8ee4bd8f052b50fab2e9e9365793374
# 1           1  HBM238.GTNW.259  a7ecf4fd858a58dcaa3bab5df455065b
# 2           2  HBM242.LSCK.393  a702c94500a2f737b722e34f6df7e7dd
# 3           3  HBM284.SBPR.357  a9d4471b41cd0d8185e12dd6c5a48e96
# 4           4  HBM285.VFDT.966  7034950e109586361e73c1b9ddb81346
# 5           5  HBM288.BBKK.828  7500e7f02589f4b4e55641f09723c3de
# 6           6  HBM295.SWJJ.888  4ea2c240173bda1bd799b0f17e55a96d
# 7           7  HBM297.MZZX.824  cf25bdcd6bae8045f6b88bb3c9a32207
# 8           8  HBM334.QWFV.953  98d54824c0eb9843865dfc3a53b4cff4
# 9           9  HBM353.NZVQ.793  3480cd404d4bacd7bb8d21be8de12c6c
#
#    total_descendants               first_descendant_id
# 0                  6  10c0c11280c00f324259fe38e2291ee4
# 1                  6  8b21db2002a5179b03532d183a4885eb
# 2                  6  6bdd149dc47782aefdd0e23599708183
# ...

# %%
manifest = []

# %%
for i in df['first_descendant_id']:
    manifest.append(f'{i}{}')

# %%
out_dir = "/teradata/sbdubey/deepcell-experiments-data/intestine-codex-stanford/"
manifest_path = os.path.join(out_dir, "manifest.txt")

lines = []
for uuid in df["first_descendant_id"]:
    lines.append(f"{uuid} /pipeline_output/expr/reg001_expr.ome.tiff")
    lines.append(f"{uuid} /pipelineConfig.json")

with open(manifest_path, "w") as f:
    f.write("\n".join(lines))

print("Saved:", manifest_path)
# Out:
# Saved: /teradata/sbdubey/deepcell-experiments-data/intestine-codex-stanford/manifest.txt

# %%
print(manifest)
# Out:
# []

# %%
with open(manifest_path, "r") as f:
    print(f.read())
# Out:
# 10c0c11280c00f324259fe38e2291ee4 /pipeline_output/expr/reg001_expr.ome.tiff
# 10c0c11280c00f324259fe38e2291ee4 /pipelineConfig.json
# 8b21db2002a5179b03532d183a4885eb /pipeline_output/expr/reg001_expr.ome.tiff
# 8b21db2002a5179b03532d183a4885eb /pipelineConfig.json
# 6bdd149dc47782aefdd0e23599708183 /pipeline_output/expr/reg001_expr.ome.tiff
# 6bdd149dc47782aefdd0e23599708183 /pipelineConfig.json
# 550f3ef14b113c24fd21b8b0750bf078 /pipeline_output/expr/reg001_expr.ome.tiff
# 550f3ef14b113c24fd21b8b0750bf078 /pipelineConfig.json
# aa54aad994ca8a64fa52b3f3945c01b7 /pipeline_output/expr/reg001_expr.ome.tiff
# aa54aad994ca8a64fa52b3f3945c01b7 /pipelineConfig.json
# 7b2b9029035d46c4ef8306fa82c8e58e /pipeline_output/expr/reg001_expr.ome.tiff
# 7b2b9029035d46c4ef8306fa82c8e58e /pipelineConfig.json
# 01510a4fb90fd303bd48c4cd51cdd14c /pipeline_output/expr/reg001_expr.ome.tiff
# 01510a4fb90fd303bd48c4cd51cdd14c /pipelineConfig.json
# ...
